# %% [markdown]
# A florist is designing bouquets using flowers of 3 types. Each bouquet must have 3 flowers,
# and repetition of flower types is allowed.
# a) List all possible bouquets using ["Rose", "Lily", "Tulip"].
# b) Display the bouquets where all three flowers are different

# %%
#Part A
from itertools import combinations_with_replacement

flowers = ["Rose", "Lily", "Tulip"]

nCr_5 = list(combinations_with_replacement(flowers, 3))

print(nCr_5)
print(len(nCr_5))

#Part B
count = 0
for i in nCr_5:
    if "Rose" in i and "Lily" in i and "Tulip" in i:
        print(i)
        count += 1

print(count)
# Out:
# [('Rose', 'Rose', 'Rose'), ('Rose', 'Rose', 'Lily'), ('Rose', 'Rose', 'Tulip'), ('Rose', 'Lily', 'Lily'), ('Rose', 'Lily', 'Tulip'), ('Rose', 'Tulip', 'Tulip'), ('Lily', 'Lily', 'Lily'), ('Lily', 'Lily', 'Tulip'), ('Lily', 'Tulip', 'Tulip'), ('Tulip', 'Tulip', 'Tulip')]
# 10
# ('Rose', 'Lily', 'Tulip')
# 1
