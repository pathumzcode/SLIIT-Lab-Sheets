# %% [markdown]
# Get a city as an input from the user. Add that city to the list, then print the updated list.

# %%
city_list = []
city = str(input("Enter the city name : "))
city_list.append(city)
print (city_list)
# Out:
# ['kadawtha']
