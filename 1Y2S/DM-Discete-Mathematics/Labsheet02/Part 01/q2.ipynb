# %% [markdown]
# Given the tuple, numbers = (1, 2, 3, 4, 5),
# I. Find the first element
# II. Find the last element
# III. Find the element at index 2
# IV. Change the element at index 4 to 10

# %%
 numbers = (1, 2, 3, 4, 5)
