# %% [markdown]
# 1. Complete below Task using Python programming,
# I. Add 20 and 15 and print the result.
# II. Subtract 12 from 50 and print the result.
# III. Multiply 8 and 7 and print the result.
# IV. Divide 100 by 25 and print the result.
# V. Find the remainder when 17 is divided by 5 and print the result.

# %%
a=20
b=15
print(a+b)
# Out:
# 35

# %%
integer = input("Int input")
print(integer)
# Out:
# 50

# %%
a=8
b=7
print(a*b)
# Out:
# 56

# %%
a=100
b=25
print(a/b)
# Out:
# 4.0

# %%
a=17
b=5
print(a%b)
# Out:
# 2
