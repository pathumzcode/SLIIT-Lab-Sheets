# %% [markdown]
# Write a Python program for an online shopping checkout system using while loop.
# • The program should keep asking the user to enter the price of items.
# • The checkout process should continue until the total bill amount reaches Rs.1000
# or more.
# • Once the total is reached, display "Checkout complete" and print the total
# amount to be paid
