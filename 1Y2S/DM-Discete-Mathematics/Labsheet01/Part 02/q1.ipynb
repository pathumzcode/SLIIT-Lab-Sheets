# %% [markdown]
# Complete below Task using Python programming,
# I. Compare two numbers (x = 15, y = 10) and
# (a) Check if x is greater than y.
# (b) Check if x is equal to y and print the result.
# (c) Check if x is not equal to y and print the result.
# II. Compare 10 and 20 using <= and print the result.
# III. Check if both 5 > 3 and 10 > 5 are true and print the result.

# %%
x = 15
y = 10

if x > y:
    print("x is greater than y")
else:
    print("y is greater than x")

if x == y:
    print("x is equal to y")
else:
    print("x is not equal to y")

a = 10
b = 20

if a < b:
    print("a is less than b")
else:
    print("a is not less than b")

c = 5
d = 3

if c > 3 and a > c:
    print("Both conditions are true")
else:
    print("At least one condition is false")
# Out:
# x is greater than y
# x is not equal to y
# a is less than b
# Both conditions are true
