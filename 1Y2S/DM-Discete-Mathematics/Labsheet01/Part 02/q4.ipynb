# %% [markdown]
# Write a Python program that takes a number n as input from the user and uses a for loop to
# calculate the sum of the first n natural numbers. Finally, display the result.

# %%
num = int(input("Enter a number: "))
total = 0
for i in range (0, num+1):
    total += i
print("The sum of the first", num, "numbers is:", total)
# Out:
# The sum of the first 5 numbers is: 15
